# %%
# !pip install flask
# Out:
# Requirement already satisfied: flask in c:\users\user\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: click>=5.1 in c:\users\user\anaconda3\lib\site-packages (from flask) (8.0.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\user\anaconda3\lib\site-packages (from flask) (2.0.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\user\anaconda3\lib\site-packages (from flask) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\user\anaconda3\lib\site-packages (from flask) (2.11.3)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from click>=5.1->flask) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask) (1.1.1)

# %%
# !pip install flask_cors
# !pip install flask-cors --upgrade
# Out:
# Requirement already satisfied: flask_cors in c:\users\user\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: Flask>=0.9 in c:\users\user\anaconda3\lib\site-packages (from flask_cors) (1.1.2)
# Requirement already satisfied: Six in c:\users\user\anaconda3\lib\site-packages (from flask_cors) (1.16.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\user\anaconda3\lib\site-packages (from Flask>=0.9->flask_cors) (2.0.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\user\anaconda3\lib\site-packages (from Flask>=0.9->flask_cors) (2.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\user\anaconda3\lib\site-packages (from Flask>=0.9->flask_cors) (8.0.3)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\user\anaconda3\lib\site-packages (from Flask>=0.9->flask_cors) (2.11.3)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from click>=5.1->Flask>=0.9->flask_cors) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=0.9->flask_cors) (1.1.1)

# %%
from flask import Flask, request, render_template, redirect
from flask_cors import CORS
import re
import random
import pandas as pd
import numpy as np
import os
from flask import Markup

app = Flask(__name__, static_url_path="/static")
Data = pd.read_csv("DataL2.csv")
Data.to_csv('DataL2.csv', index=None)
Data_eng = pd.read_csv("Data_eng.csv")
Data_jpn = pd.read_csv("Data_jpn.csv")
Data = Data.dropna()
Data_eng=Data_eng.dropna()
Data_jpn=Data_jpn.dropna()

CORS(app)

MainImage = Data['MainImage']
Title = Data['Title']
DataFilter = Data['DataFilter']
PlaceFilter = Data['PlaceFilter']
Subtitle = Data['Subtitle']
DramaPlace = Data['DramaPlace']
Dialogue = Data['Dialogue']
Place = Data['Place']
Address = Data['Address']
LatitudeValue = Data['LatitudeValue']
LongitudeValue = Data['LongitudeValue']
SubImage = Data['SubImage']

# FLASK API 구현
# FLASK API 생성 예제 1
# 10PJ.html (http://127.0.0.1:5000/10PJ)
@app.route("/", methods=['GET','POST'])
def MainPage():
    return render_template('10PJ.html',
                            len = len(Place),
                            DataFilter = DataFilter,
                            Place = Place,
                            MainImage = MainImage,
                            Title = Title,
                            Subtitle = Subtitle)

# FLASK API 생성 예제 2
# locate-single.html (http://127.0.0.1:5000/locateSingle)
@app.route("/locatesingle", methods=['GET', 'POST'])
def LocatePage():
    InputPlace = request.args.get('Place')
    IDX = np.where(Place == InputPlace)[0]
    #return redirect("http://127.0.0.1:5000/locatesingle/"+result)
    return render_template('locatesingle.html',
                            DramaPlace=DramaPlace[IDX].values[0],
                            DataFilter=DataFilter[IDX],
                            LatitudeValue=LatitudeValue[IDX].values[0],
                            LongitudeValue=LongitudeValue[IDX].values[0],
                            Dialogue=Markup(Dialogue[IDX].values[0]),
                            Place=Place[IDX].values[0],
                            Address=Address[IDX].values[0],
                            SubImage=SubImage[IDX])

# FLASK API 생성 예제 3
# allmap.html (http://127.0.0.1:5000/map)
@app.route("/map", methods=['GET','POST'])
def AllMap():
    return render_template('map.html')

# FLASK API 생성 예제 4
# allmap.html (http://127.0.0.1:5000/coursejj)
@app.route("/coursejj", methods=['GET','POST'])
def Coursejj():
    return render_template('course01jj.html')

@app.route("/coursegj", methods=['GET','POST'])
def Coursegj():
    return render_template('course02gj.html')

Gw = pd.read_csv("gangwon_place.csv", encoding="cp949")
Gw = Gw.dropna()
GwFilter = Gw['filter']
GwName = Gw['name']
GwDistance = Gw['distance']
GwImg = Gw['img']
GwLink = Gw['link']
GwDetail = Gw['detail']          
@app.route("/coursegw", methods=['GET','POST'])
def Coursegw():
    return render_template('course03gw.html',
                           lengw = len(GwName),
                           GwFilter = GwFilter,
                           GwName = GwName,
                           GwDistance = GwDistance,
                           GwImg = GwImg,
                           GwLink = GwLink,
                           GwDetail = GwDetail)

@app.route("/coursesu", methods=['GET','POST'])
def Coursesu():
    return render_template('course04su.html')

# FLASK API 생성 예제 5
# allmap.html (http://127.0.0.1:5000/about)
@app.route("/about", methods=['GET','POST'])
def About():
    return render_template('about.html')

# FLASK API 생성 예제 6
MainImage_eng=Data_eng['MainImage']
Title_eng=Data_eng['Title']
DataFilter_eng=Data_eng['DataFilter']
PlaceFilter_eng=Data_eng['PlaceFilter']
Subtitle_eng=Data_eng['Subtitle']
DramaPlace_eng=Data_eng['DramaPlace']
Dialogue_eng=Data_eng['Dialogue']
Place_eng=Data_eng['Place']
Address_eng=Data_eng['Address']
LatitudeValue_eng=Data_eng['LatitudeValue']
LongitudeValue_eng=Data_eng['LongitudeValue']
SubImage_eng=Data_eng['SubImage']

MainImage_jpn=Data_jpn['MainImage']
Title_jpn=Data_jpn['Title']
DataFilter_jpn=Data_jpn['DataFilter']
PlaceFilter_jpn=Data_jpn['PlaceFilter']
Subtitle_jpn=Data_jpn['Subtitle']
DramaPlace_jpn=Data_jpn['DramaPlace']
Dialogue_jpn=Data_jpn['Dialogue']
Place_jpn=Data_jpn['Place']
Address_jpn=Data_jpn['Address']
LatitudeValue_jpn=Data_jpn['LatitudeValue']
LongitudeValue_jpn=Data_jpn['LongitudeValue']
SubImage_jpn=Data_jpn['SubImage']

@app.route("/engmain", methods=['GET','POST'])
def EngMain():
    return render_template('engmain.html',
                            len = len(Place_eng),
                            DataFilter_eng=DataFilter_eng,
                            Place_eng=Place_eng,
                            MainImage_eng=MainImage_eng,
                            Title_eng=Title_eng,
                            Subtitle_eng=Subtitle_eng)
@app.route("/engsub", methods=['GET','POST'])
def EngSub():
    InputPlace_eng = request.args.get('Place')
    IDX = np.where(Place_eng == InputPlace_eng)[0]
    return render_template('engsub.html',
                            DramaPlace_eng=DramaPlace_eng[IDX].values[0],
                            DataFilter_eng=DataFilter_eng[IDX],
                            LatitudeValue_eng=LatitudeValue_eng[IDX].values[0],
                            LongitudeValue_eng=LongitudeValue_eng[IDX].values[0],
                            Dialogue_eng=Markup(Dialogue_eng[IDX].values[0]),
                            Place_eng=Place_eng[IDX].values[0],
                            Address_eng=Address_eng[IDX].values[0],
                            SubImage_eng=SubImage_eng[IDX])
@app.route("/engabout", methods=['GET', 'POST'])
def ENGAbout():
    return render_template('engabout.html')

@app.route("/jpnmain", methods=['GET','POST'])
def JpnMain():
    return render_template('jpnmain.html',
                            len = len(Place_jpn),
                            DataFilter_jpn=DataFilter_jpn,
                            Place_jpn=Place_jpn,
                            MainImage_jpn=MainImage_jpn,
                            Title_jpn=Title_jpn,
                            Subtitle_jpn=Subtitle_jpn)
@app.route("/jpngub", methods=['GET','POST'])
def JpnSub():
    InputPlace_jpn = request.args.get('Place')
    IDX = np.where(Place_jpn == InputPlace_jpn)[0]
    return render_template('jpnsub.html',
                            DramaPlace_jpn=DramaPlace_jpn[IDX].values[0],
                            DataFilter_jpn=DataFilter_jpn[IDX],
                            LatitudeValue_jpn=LatitudeValue_jpn[IDX].values[0],
                            LongitudeValue_jpn=LongitudeValue_jpn[IDX].values[0],
                            Dialogue_jpn=Markup(Dialogue_jpn[IDX].values[0]),
                            Place_jpn=Place_jpn[IDX].values[0],
                            Address_jpn=Address_jpn[IDX].values[0],
                            SubImage_jpn=SubImage_jpn[IDX])
@app.route("/jpnabout", methods=['GET', 'POST'])
def JPNAbout():
    return render_template('jpnabout.html')

# API 작동
app.run(host='localhost', port='5000')
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://localhost:5000 (Press CTRL+C to quit)
# 127.0.0.1 - - [20/Jun/2022 15:46:16] "GET /coursejj HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Jun/2022 15:46:22] "GET /static/assets/bower_components/fontawesome/css/font-awesome.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:22] "GET /static/assets/bower_components/bootstrap/dist/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:22] "GET /static/assets/bower_components/flickity/dist/flickity.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:22] "GET /static/assets/bower_components/pixeden-stroke-7-icon/pe-icon-7-stroke/dist/pe-icon-7-stroke.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:22] "GET /static/assets/bower_components/photoswipe/dist/photoswipe.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:22] "GET /static/assets/bower_components/photoswipe/dist/default-skin/default-skin.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:22] "GET /static/assets/css/piroll.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:22] "GET /static/assets/css/custom.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:23] "GET /static/assets/bower_components/jquery/dist/jquery.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:23] "GET /static/assets/bower_components/gsap/src/minified/TweenMax.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:23] "GET /static/assets/2521/전주2.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Jun/2022 15:46:23] "GET /static/assets/2521/전주.png HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Jun/2022 15:46:23] "GET /static/assets/2521/driplogoblack.png HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:23] "GET /static/assets/2521/1_01_01.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:23] "GET /static/assets/2521/1_02_01.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:23] "GET /static/assets/2521/1_07_01.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:23] "GET /static/assets/bower_components/gsap/src/minified/plugins/ScrollToPlugin.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:23] "GET /static/assets/plugins/nk-share/nk-share.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:24] "GET /static/assets/bower_components/sticky-kit/dist/sticky-kit.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:24] "GET /static/assets/bower_components/tether/dist/js/tether.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:24] "GET /static/assets/bower_components/bootstrap/dist/js/bootstrap.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:24] "GET /static/assets/bower_components/jarallax/dist/jarallax.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:24] "GET /static/assets/bower_components/isotope/dist/isotope.pkgd.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:24] "GET /static/assets/bower_components/flickity/dist/flickity.pkgd.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:24] "GET /static/assets/bower_components/jarallax/dist/jarallax-video.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:24] "GET /static/assets/bower_components/photoswipe/dist/photoswipe.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:24] "GET /static/assets/bower_components/photoswipe/dist/photoswipe-ui-default.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:24] "GET /static/assets/bower_components/jquery-form/dist/jquery.form.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:24] "GET /static/assets/bower_components/hammer.js/hammer.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:24] "GET /static/assets/bower_components/jquery-validation/dist/jquery.validate.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:25] "GET /static/assets/bower_components/social-likes/dist/social-likes.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:25] "GET /static/assets/bower_components/nanoscroller/bin/javascripts/jquery.nanoscroller.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:25] "GET /static/assets/bower_components/keymaster/keymaster.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:25] "GET /static/assets/js/piroll-init.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:25] "GET /static/assets/2521/1_03_01.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:25] "GET /static/assets/js/piroll.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:25] "GET /static/assets/js/demo.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:25] "GET /static/assets/2521/1_06_01.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:31] "GET /coursegw HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Jun/2022 15:46:31] "GET /static/assets/bower_components/bootstrap/dist/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:31] "GET /static/assets/bower_components/fontawesome/css/font-awesome.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:31] "GET /static/assets/bower_components/pixeden-stroke-7-icon/pe-icon-7-stroke/dist/pe-icon-7-stroke.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:32] "GET /static/assets/bower_components/flickity/dist/flickity.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:32] "GET /static/assets/bower_components/photoswipe/dist/photoswipe.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:32] "GET /static/assets/bower_components/photoswipe/dist/default-skin/default-skin.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:32] "GET /static/assets/css/piroll.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:32] "GET /static/assets/css/custom.css HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:32] "GET /static/assets/bower_components/jquery/dist/jquery.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:32] "GET /static/assets/bower_components/gsap/src/minified/TweenMax.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:32] "GET /static/assets/2521/driplogoblack.png HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:32] "GET /static/assets/2521/강원.png HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:32] "GET /static/assets/2521/강원2.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:32] "GET /static/assets/2521/3_05_01.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:32] "GET /static/assets/2521/3_04_01.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:32] "GET /static/assets/2521/3_02_01.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/gsap/src/minified/plugins/ScrollToPlugin.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/tether/dist/js/tether.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/plugins/nk-share/nk-share.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/bootstrap/dist/js/bootstrap.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/sticky-kit/dist/sticky-kit.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/jarallax/dist/jarallax.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/jarallax/dist/jarallax-video.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/flickity/dist/flickity.pkgd.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/isotope/dist/isotope.pkgd.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/photoswipe/dist/photoswipe.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/photoswipe/dist/photoswipe-ui-default.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/jquery-form/dist/jquery.form.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/jquery-validation/dist/jquery.validate.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/hammer.js/hammer.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/social-likes/dist/social-likes.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/nanoscroller/bin/javascripts/jquery.nanoscroller.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/bower_components/keymaster/keymaster.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:33] "GET /static/assets/js/piroll.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:34] "GET /static/assets/js/piroll-init.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:34] "GET /static/assets/js/demo.js HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:34] "GET /static/assets/2521/3_03_01.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:34] "GET /static/assets/2521/3_06_01.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [20/Jun/2022 15:46:34] "GET /static/assets/2521/3_01_02.jpg HTTP/1.1" 304 -
